# %%
import numpy as np
import pandas as pd

# %%
Data = pd.read_csv("Mouse_cDNA_Length.csv")

# %%
Data
# Out:
#        chrom     name strand  exonCount  cDNALength
# 0       chr1   Adora1      -          3        4968
# 1       chr1    Sntg1      -         21        4887
# 2       chr1   Adgrb3      -         31        5448
# 3       chr1    Prim2      -         14        1975
# 4       chr1    Cflar      +         10        6572
# ...      ...      ...    ...        ...         ...
# 22352  chr19    Prdx3      -          7        1478
# 22353  chr19   Gm7102      -          1        1624
# 22354  chr19   Gm6020      +          1          66
# 22355  chr19   Csf2ra      -         12        1849
# 22356  chr19  Gm21060      -          1         168
#
# [22357 rows x 5 columns]

# %%
m6A = pd.read_csv("Mouse_Prob_Counts.csv")

# %%
m6A
# Out:
#           name  Count
# 0         Xkr4      2
# 1          Rp1      6
# 2        Sox17      0
# 3       Mrpl15      2
# 4       Lypla1      0
# ...        ...    ...
# 22352  Gm21996      0
# 22353  Gm20837      0
# 22354  Gm21860      0
# 22355    Erdr1      0
# 22356  Gm21748      0
#
# [22357 rows x 2 columns]

# %%
Data = pd.merge(Data, m6A, how="inner", on=["name"])

# %%
Data
# Out:
#        chrom     name strand  exonCount  cDNALength  Count
# 0       chr1   Adora1      -          3        4968      0
# 1       chr1    Sntg1      -         21        4887      0
# 2       chr1   Adgrb3      -         31        5448      3
# 3       chr1    Prim2      -         14        1975      0
# 4       chr1    Cflar      +         10        6572      0
# ...      ...      ...    ...        ...         ...    ...
# 22352  chr19    Prdx3      -          7        1478      0
# 22353  chr19   Gm7102      -          1        1624      4
# 22354  chr19   Gm6020      +          1          66      0
# 22355  chr19   Csf2ra      -         12        1849      4
# 22356  chr19  Gm21060      -          1         168      0
#
# [22357 rows x 6 columns]

# %%
RAC = pd.read_csv("Count_RAC.csv")

# %%
Data = pd.merge(Data, RAC, how="inner", on=["name"])

# %%
Half = pd.read_csv("GSE86336_halflife_changes_WTvsKO.txt", sep="\t")

# %%
Half
# Out:
#          name     KO     WT  log2(KO/WT)
# 0        Rln1   0.93   0.57       0.7167
# 1      Zfp473   1.44   0.59       1.2836
# 2       Mkrn3   1.01   0.59       0.7713
# 3       Snai1   0.66   0.59       0.1629
# 4       Grrp1   7.08   0.59       3.5773
# ...       ...    ...    ...          ...
# 7744   Dnmt3l   1.25  98.00      -6.2875
# 7745    Tnni3  11.00  98.00      -3.1551
# 7746  Plekhb2  21.19  98.00      -2.2097
# 7747     Uxs1  13.30  98.00      -2.8816
# 7748     Ybx2  15.92  98.00      -2.6219
#
# [7749 rows x 4 columns]

# %%
Data = pd.merge(Data, Half, how="inner", on=["name"])

# %%
Data
# Out:
#       chrom    name strand  exonCount  cDNALength  Count    RAC     KO     WT  \
# 0      chr1   Prim2      -         14        1975      0   53.0   8.48  11.60
# 1      chr1  Lactb2      -          7        4494      0   92.0   2.76   3.23
# 2      chr1   Pgap1      -         27       10583      0  238.0   5.22   3.89
# 3      chr1   Bmpr2      +         13       12899      4  291.0   3.54   1.39
# 4      chr1   Xrcc5      +         21        2555      0   77.0  26.55  21.49
# ...     ...     ...    ...        ...         ...    ...    ...    ...    ...
# 7744  chr19   Pdzd8      -          5        7076      7  197.0   4.74   2.30
# 7745  chr19  Nanos1      +          1        3927      1   83.0   7.98   1.02
# 7746  chr19   Eif3a      -         22        5176      3  156.0   4.86   3.19
# 7747  chr19   Prdx3      -          7        1478      0   29.0   5.59   5.92
# 7748  chr19  Csf2ra      -         12        1849      4   78.0   6.77   9.36
#
#       log2(KO/WT)
# 0         -0.4521
# 1         -0.2297
# 2          0.4246
# 3          1.3516
# 4          0.3049
# ...           ...
# 7744       1.0443
# 7745       2.9659
# 7746       0.6063
# 7747      -0.0836
# 7748      -0.4672
#
# [7749 rows x 10 columns]

# %%
Data = Data[Data["Count"]>0]
Data = Data.reset_index(drop = True)

# %%
Data
# Out:
#       chrom      name strand  exonCount  cDNALength  Count    RAC     KO  \
# 0      chr1     Bmpr2      +         13       12899      4  291.0   3.54
# 1      chr1     Usp37      -         26        4974      1  147.0   2.60
# 2      chr1      Pask      -         18        5779      3  150.0  11.16
# 3      chr1    Clasp1      +         42        7910     10  243.0   6.21
# 4      chr1  Mapkapk2      -         10        2854      1   60.0  12.06
# ...     ...       ...    ...        ...         ...    ...    ...    ...
# 4404  chr19  Fam160b1      +         17        5630      1  141.0   1.98
# 4405  chr19     Pdzd8      -          5        7076      7  197.0   4.74
# 4406  chr19    Nanos1      +          1        3927      1   83.0   7.98
# 4407  chr19     Eif3a      -         22        5176      3  156.0   4.86
# 4408  chr19    Csf2ra      -         12        1849      4   78.0   6.77
#
#          WT  log2(KO/WT)
# 0      1.39       1.3516
# 1      3.09      -0.2469
# 2      7.62       0.5514
# 3      4.73       0.3935
# 4     15.54      -0.3658
# ...     ...          ...
# 4404   1.94       0.0324
# 4405   2.30       1.0443
# 4406   1.02       2.9659
# 4407   3.19       0.6063
# 4408   9.36      -0.4672
#
# [4409 rows x 10 columns]

# %%
data1 = Data[Data["exonCount"]==1]
data1 = data1.reset_index(drop = True)

# %%
data1
# Out:
#      chrom      name strand  exonCount  cDNALength  Count    RAC    KO    WT  \
# 0     chr1      Rrs1      +          1        2048      7   53.0  9.96  1.73
# 1     chr1     Mars2      +          1       11294     11  253.0  1.45  0.88
# 2     chr1      Fzd7      +          1        4532      4   86.0  2.47  1.06
# 3     chr1  Tmem185b      +          1        2824      5   64.0  1.37  1.10
# 4     chr1     Zbed6      -          1        5007     14  132.0  2.62  1.96
# ..     ...       ...    ...        ...         ...    ...    ...   ...   ...
# 96   chr19   Fam122a      -          1         855      3   29.0  4.95  2.16
# 97   chr19    Ranbp6      -          1        4575     15  131.0  3.33  1.67
# 98   chr19    Cstf2t      +          1        3750      3   92.0  3.92  2.11
# 99   chr19      Hps6      +          1        2696      4   67.0  9.41  0.82
# 100  chr19    Nanos1      +          1        3927      1   83.0  7.98  1.02
#
#      log2(KO/WT)
# 0         2.5233
# 1         0.7153
# 2         1.2199
# 3         0.3114
# 4         0.4176
# ..           ...
# 96        1.1997
# 97        0.9954
# 98        0.8921
# 99        3.5227
# 100       2.9659
#
# [101 rows x 10 columns]

# %%
cDNA = data1["RAC"].tolist()

# %%
data2 = pd.DataFrame(columns = Data.columns.to_list())

# %%
data2
# Out:
# Empty DataFrame
# Columns: [chrom, name, strand, exonCount, cDNALength, Count, RAC, KO, WT, log2(KO/WT)]
# Index: []

# %%
data3 = Data[Data["exonCount"]>=2]
data3 = data3.reset_index(drop = True)

# %%
data3
# Out:
#       chrom      name strand  exonCount  cDNALength  Count    RAC     KO  \
# 0      chr1     Bmpr2      +         13       12899      4  291.0   3.54
# 1      chr1     Usp37      -         26        4974      1  147.0   2.60
# 2      chr1      Pask      -         18        5779      3  150.0  11.16
# 3      chr1    Clasp1      +         42        7910     10  243.0   6.21
# 4      chr1  Mapkapk2      -         10        2854      1   60.0  12.06
# ...     ...       ...    ...        ...         ...    ...    ...    ...
# 4303  chr19    Nhlrc2      +         11        3934      3   99.0   8.63
# 4304  chr19  Fam160b1      +         17        5630      1  141.0   1.98
# 4305  chr19     Pdzd8      -          5        7076      7  197.0   4.74
# 4306  chr19     Eif3a      -         22        5176      3  156.0   4.86
# 4307  chr19    Csf2ra      -         12        1849      4   78.0   6.77
#
#          WT  log2(KO/WT)
# 0      1.39       1.3516
# 1      3.09      -0.2469
# 2      7.62       0.5514
# 3      4.73       0.3935
# 4     15.54      -0.3658
# ...     ...          ...
# 4303   4.70       0.8776
# 4304   1.94       0.0324
# 4305   2.30       1.0443
# 4306   3.19       0.6063
# 4307   9.36      -0.4672
#
# [4308 rows x 10 columns]

# %%
for i in range(len(cDNA)):
    
    length = cDNA[i]
    df = data3[(data3["RAC"]==length)]
    
    if len(df)>=1:
        df = df.sample(n=1, random_state=1)
        data2 = data2.append(df)
        data3 = data3.append(df)
        data3 = data3.drop_duplicates(subset=["name"], keep=False)
        data3 = data3.reset_index(drop = True)
        
    if len(df)==0:
        df = data1[data1["RAC"]==length]
        df = df.sample(n=1, random_state=1)
        data1 = data1.append(df)
        data1 = data1.drop_duplicates(subset=["name"], keep=False)

# %%
data1
# Out:
#      chrom      name strand  exonCount  cDNALength  Count    RAC    KO    WT  \
# 0     chr1      Rrs1      +          1        2048      7   53.0  9.96  1.73
# 1     chr1     Mars2      +          1       11294     11  253.0  1.45  0.88
# 2     chr1      Fzd7      +          1        4532      4   86.0  2.47  1.06
# 3     chr1  Tmem185b      +          1        2824      5   64.0  1.37  1.10
# 4     chr1     Zbed6      -          1        5007     14  132.0  2.62  1.96
# ..     ...       ...    ...        ...         ...    ...    ...   ...   ...
# 96   chr19   Fam122a      -          1         855      3   29.0  4.95  2.16
# 97   chr19    Ranbp6      -          1        4575     15  131.0  3.33  1.67
# 98   chr19    Cstf2t      +          1        3750      3   92.0  3.92  2.11
# 99   chr19      Hps6      +          1        2696      4   67.0  9.41  0.82
# 100  chr19    Nanos1      +          1        3927      1   83.0  7.98  1.02
#
#      log2(KO/WT)
# 0         2.5233
# 1         0.7153
# 2         1.2199
# 3         0.3114
# 4         0.4176
# ..           ...
# 96        1.1997
# 97        0.9954
# 98        0.8921
# 99        3.5227
# 100       2.9659
#
# [101 rows x 10 columns]

# %%
data2
# Out:
#       chrom      name strand exonCount cDNALength Count    RAC     KO    WT  \
# 2217   chr9  Aasdhppt      -         6       2870     1   53.0   7.51  4.48
# 7      chr1    Rasal2      -        18      10047     1  253.0   2.66  1.83
# 3408  chr14     Fdft1      -         8       2860     2   86.0   8.52  4.52
# 215    chr1    Sccpdh      +        12       1948     1   64.0   3.19  4.78
# 1606   chr7    Ppfia3      -        30       4865     4  132.0   7.73  4.69
# ...     ...       ...    ...       ...        ...   ...    ...    ...   ...
# 2783  chr11   Zcchc10      +         4       1267     5   29.0   3.58  1.63
# 3036  chr12     Smek1      -        15       4555    11  131.0   3.70  1.80
# 2139   chr9     Ccpg1      +         9       3151     4   92.0   8.41  5.93
# 608    chr3    Rnf115      +         9       2209     1   67.0   6.79  7.28
# 3613  chr16     Itgb5      +        15       3090     1   83.0  25.14  9.07
#
#       log2(KO/WT)
# 2217       0.7472
# 7          0.5386
# 3408       0.9159
# 215       -0.5817
# 1606       0.7224
# ...           ...
# 2783       1.1348
# 3036       1.0384
# 2139       0.5056
# 608       -0.1011
# 3613       1.4709
#
# [101 rows x 10 columns]

# %%
Plot = data1.append(data2)
Plot = Plot.reset_index(drop = True)

# %%
Plot.to_csv("Data_Single_VS_Multiple.csv", index=0)
